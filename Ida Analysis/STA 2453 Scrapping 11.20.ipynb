# %%
import requests
print('Requests version: ' + requests.__version__)

import bs4
print('Beautiful Soup version: ' + bs4.__version__)
from bs4 import BeautifulSoup
# Out:
# Requests version: 2.22.0
# Beautiful Soup version: 4.8.0

# %%
# https://proxiesapi.com/blog/scraping-listings-from-realtor-with-python-and-bea.html.php
headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.11 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9',
'Accept-Encoding': 'identity', 'Accept-Language': 'en-CA,en;q=0.6'
}
#'Accept-Encoding': 'identity'

url = 'https://www.realtor.ca/on/toronto/condos-for-sale'

response=requests.get(url,headers=headers)

#print(response.content)

soup=BeautifulSoup(response.content)

# %%
sales = soup.find_all(attrs={'class':'blockLink listingDetailsLink'})
sales
# Out:
# [<a class="blockLink listingDetailsLink" data-binding="href=DetailsURL" href="/real-estate/23993307/708-75-st-nicholas-street-toronto">
#  <div class="listingCardOuterBody">
#  <div class="listingCardImageCon">
#  <img alt="708 75 St Nicholas Street, Toronto, Ontario " class="listingCardImage" data-binding="src=ImageURL,alt=Address" src="https://cdn.realtor.ca/listings/TS637793895698200000/reb14/medres/3/h4124943_1.jpg">
#  </img></div>
#  <div class="listingCardBody">
#  <div class="listingCardTopBody" data-binding="hidden=ListingNotFound">
#  <div class="listingCardMLS" style="display: none;">MLS<sup>®</sup>: <span data-binding="innertext=MLSNumber,title=MLSNumber" title="H4124943">H4124943</span></div>
#  <div class="listingCardPrice" data-binding="data-value-cad={Price},innertext=DisplayPrice,title=ConvertedPrice" data-value-cad="$687,500" title="$687,500 ">$687,500 </div>
#  <div class="listingCardAddress" data-binding="innertext=Address">
#                          708 75 St Nicholas Street, Toronto, Ontario
#                      </div>
#  </div>
#  <div class="listingCardIconStrip" data-binding="FooterIcons,visible=ShowFooterIcons">
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">1</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bed-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bedrooms</div>
#  </div>
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">1</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bath-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bathrooms</div>
#  </div>
#  </div>
#  <div class="listingCardOfficeName" data-binding="innertext=OfficeNameAndType">RE/MAX Real Estate Centre Inc.</div>
#  </div>
#  </div>
#  </a>,
#  <a class="blockLink listingDetailsLink" data-binding="href=DetailsURL" href="/real-estate/23993014/919-20-blue-jays-way-toronto-waterfront-communities-c1">
#  <div class="listingCardOuterBody">
#  <div class="listingCardImageCon">
#  <img alt="#919 -20 BLUE JAYS WAY, Toronto, Ontario " class="listingCardImage" data-binding="src=ImageURL,alt=Address" src="https://cdn.realtor.ca/listings/TS637793864597730000/reb82/medres/6/c5487696_1.jpg">
#  </img></div>
#  <div class="listingCardBody">
#  <div class="listingCardTopBody" data-binding="hidden=ListingNotFound">
#  <div class="listingCardMLS" style="display: none;">MLS<sup>®</sup>: <span data-binding="innertext=MLSNumber,title=MLSNumber" title="C5487696">C5487696</span></div>
#  <div class="listingCardPrice" data-binding="data-value-cad={Price},innertext=DisplayPrice,title=ConvertedPrice" data-value-cad="$678,000" title="$678,000 ">$678,000 </div>
#  <div class="listingCardAddress" data-binding="innertext=Address">
#                          #919 -20 BLUE JAYS WAY, Toronto, Ontario
#                      </div>
#  </div>
#  <div class="listingCardIconStrip" data-binding="FooterIcons,visible=ShowFooterIcons">
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">1</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bed-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bedrooms</div>
#  </div>
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">1</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bath-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bathrooms</div>
#  </div>
#  </div>
#  <div class="listingCardOfficeName" data-binding="innertext=OfficeNameAndType">TORONTO REAL ESTATE PLUS INC., Brokerage</div>
#  </div>
#  </div>
#  </a>,
#  <a class="blockLink listingDetailsLink" data-binding="href=DetailsURL" href="/real-estate/23992979/303-1000-king-st-w-toronto-niagara">
#  <div class="listingCardOuterBody">
#  <div class="listingCardImageCon">
#  <img alt="#303 -1000 KING ST W, Toronto, Ontario " class="listingCardImage" data-binding="src=ImageURL,alt=Address" src="https://cdn.realtor.ca/listings/TS637793961452100000/reb82/medres/9/c5487569_1.jpg">
#  </img></div>
#  <div class="listingCardBody">
#  <div class="listingCardTopBody" data-binding="hidden=ListingNotFound">
#  <div class="listingCardMLS" style="display: none;">MLS<sup>®</sup>: <span data-binding="innertext=MLSNumber,title=MLSNumber" title="C5487569">C5487569</span></div>
#  <div class="listingCardPrice" data-binding="data-value-cad={Price},innertext=DisplayPrice,title=ConvertedPrice" data-value-cad="$599,000" title="$599,000 ">$599,000 </div>
#  <div class="listingCardAddress" data-binding="innertext=Address">
#                          #303 -1000 KING ST W, Toronto, Ontario
#                      </div>
#  </div>
#  <div class="listingCardIconStrip" data-binding="FooterIcons,visible=ShowFooterIcons">
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">1</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bed-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bedrooms</div>
#  </div>
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">1</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bath-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bathrooms</div>
#  </div>
#  </div>
#  <div class="listingCardOfficeName" data-binding="innertext=OfficeNameAndType">SUTTON GROUP-ASSOCIATES REALTY INC., Brokerage</div>
#  </div>
#  </div>
#  </a>,
#  <a class="blockLink listingDetailsLink" data-binding="href=DetailsURL" href="/real-estate/23993179/19-18-applewood-lane-toronto-etobicoke-west-mall">
#  <div class="listingCardOuterBody">
#  <div class="listingCardImageCon">
#  <img alt="#19 -18 APPLEWOOD LANE, Toronto, Ontario " class="listingCardImage" data-binding="src=ImageURL,alt=Address" src="https://cdn.realtor.ca/listings/TS637793864664230000/reb82/medres/1/w5487681_1.jpg">
#  </img></div>
#  <div class="listingCardBody">
#  <div class="listingCardTopBody" data-binding="hidden=ListingNotFound">
#  <div class="listingCardMLS" style="display: none;">MLS<sup>®</sup>: <span data-binding="innertext=MLSNumber,title=MLSNumber" title="W5487681">W5487681</span></div>
#  <div class="listingCardPrice" data-binding="data-value-cad={Price},innertext=DisplayPrice,title=ConvertedPrice" data-value-cad="$899,000" title="$899,000 ">$899,000 </div>
#  <div class="listingCardAddress" data-binding="innertext=Address">
#                          #19 -18 APPLEWOOD LANE, Toronto, Ontario
#                      </div>
#  </div>
#  <div class="listingCardIconStrip" data-binding="FooterIcons,visible=ShowFooterIcons">
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">3</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bed-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bedrooms</div>
#  </div>
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">3</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bath-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bathrooms</div>
#  </div>
#  </div>
#  <div class="listingCardOfficeName" data-binding="innertext=OfficeNameAndType">BAY STREET GROUP INC., Brokerage</div>
#  </div>
#  </div>
#  </a>,
#  <a class="blockLink listingDetailsLink" data-binding="href=DetailsURL" href="/real-estate/23992975/4707-14-york-st-toronto-waterfront-communities-c1">
#  <div class="listingCardOuterBody">
#  <div class="listingCardImageCon">
#  <img alt="#4707 -14 YORK ST, Toronto, Ontario " class="listingCardImage" data-binding="src=ImageURL,alt=Address" src="https://cdn.realtor.ca/listings/TS637793961451430000/reb82/medres/2/c5487562_1.jpg">
#  </img></div>
#  <div class="listingCardBody">
#  <div class="listingCardTopBody" data-binding="hidden=ListingNotFound">
#  <div class="listingCardMLS" style="display: none;">MLS<sup>®</sup>: <span data-binding="innertext=MLSNumber,title=MLSNumber" title="C5487562">C5487562</span></div>
#  <div class="listingCardPrice" data-binding="data-value-cad={Price},innertext=DisplayPrice,title=ConvertedPrice" data-value-cad="$670,000" title="$670,000 ">$670,000 </div>
#  <div class="listingCardAddress" data-binding="innertext=Address">
#                          #4707 -14 YORK ST, Toronto, Ontario
#                      </div>
#  </div>
#  <div class="listingCardIconStrip" data-binding="FooterIcons,visible=ShowFooterIcons">
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">1 + 1</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bed-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bedrooms</div>
#  </div>
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">1</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bath-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bathrooms</div>
#  </div>
#  </div>
#  <div class="listingCardOfficeName" data-binding="innertext=OfficeNameAndType">CENTURY 21 KING'S QUAY REAL ESTATE INC., Brokerage</div>
#  </div>
#  </div>
#  </a>,
#  <a class="blockLink listingDetailsLink" data-binding="href=DetailsURL" href="/real-estate/23992988/5011-8-the-esplanade-ave-toronto-waterfront-communities-c8">
#  <div class="listingCardOuterBody">
#  <div class="listingCardImageCon">
#  <img alt="#5011 -8 THE ESPLANADE AVE, Toronto, Ontario " class="listingCardImage" data-binding="src=ImageURL,alt=Address" src="https://cdn.realtor.ca/listings/TS637793862167370000/reb82/medres/4/c5487594_1.jpg">
#  </img></div>
#  <div class="listingCardBody">
#  <div class="listingCardTopBody" data-binding="hidden=ListingNotFound">
#  <div class="listingCardMLS" style="display: none;">MLS<sup>®</sup>: <span data-binding="innertext=MLSNumber,title=MLSNumber" title="C5487594">C5487594</span></div>
#  <div class="listingCardPrice" data-binding="data-value-cad={Price},innertext=DisplayPrice,title=ConvertedPrice" data-value-cad="$945,000" title="$945,000 ">$945,000 </div>
#  <div class="listingCardAddress" data-binding="innertext=Address">
#                          #5011 -8 THE ESPLANADE AVE, Toronto, Ontario
#                      </div>
#  </div>
#  <div class="listingCardIconStrip" data-binding="FooterIcons,visible=ShowFooterIcons">
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">1 + 1</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bed-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bedrooms</div>
#  </div>
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">2</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bath-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bathrooms</div>
#  </div>
#  </div>
#  <div class="listingCardOfficeName" data-binding="innertext=OfficeNameAndType">UB REALTY INC., Brokerage</div>
#  </div>
#  </div>
#  </a>,
#  <a class="blockLink listingDetailsLink" data-binding="href=DetailsURL" href="/real-estate/23992974/1907-10-muirhead-rd-toronto-pleasant-view">
#  <div class="listingCardOuterBody">
#  <div class="listingCardImageCon">
#  <img alt="#1907 -10 MUIRHEAD RD, Toronto, Ontario " class="listingCardImage" data-binding="src=ImageURL,alt=Address" src="https://cdn.realtor.ca/listings/TS637793862124930000/reb82/medres/4/c5487554_1.jpg">
#  </img></div>
#  <div class="listingCardBody">
#  <div class="listingCardTopBody" data-binding="hidden=ListingNotFound">
#  <div class="listingCardMLS" style="display: none;">MLS<sup>®</sup>: <span data-binding="innertext=MLSNumber,title=MLSNumber" title="C5487554">C5487554</span></div>
#  <div class="listingCardPrice" data-binding="data-value-cad={Price},innertext=DisplayPrice,title=ConvertedPrice" data-value-cad="$469,000" title="$469,000 ">$469,000 </div>
#  <div class="listingCardAddress" data-binding="innertext=Address">
#                          #1907 -10 MUIRHEAD RD, Toronto, Ontario
#                      </div>
#  </div>
#  <div class="listingCardIconStrip" data-binding="FooterIcons,visible=ShowFooterIcons">
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">1 + 1</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bed-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bedrooms</div>
#  </div>
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">1</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bath-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bathrooms</div>
#  </div>
#  </div>
#  <div class="listingCardOfficeName" data-binding="innertext=OfficeNameAndType">SUTTON GROUP - SUMMIT REALTY INC., Brokerage</div>
#  </div>
#  </div>
#  </a>,
#  <a class="blockLink listingDetailsLink" data-binding="href=DetailsURL" href="/real-estate/23993009/2611-29-singer-crt-toronto-bayview-village">
#  <div class="listingCardOuterBody">
#  <div class="listingCardImageCon">
#  <img alt="#2611 -29 SINGER CRT, Toronto, Ontario " class="listingCardImage" data-binding="src=ImageURL,alt=Address" src="https://cdn.realtor.ca/listings/TS637793950616570000/reb82/medres/0/c5487680_1.jpg">
#  </img></div>
#  <div class="listingCardBody">
#  <div class="listingCardTopBody" data-binding="hidden=ListingNotFound">
#  <div class="listingCardMLS" style="display: none;">MLS<sup>®</sup>: <span data-binding="innertext=MLSNumber,title=MLSNumber" title="C5487680">C5487680</span></div>
#  <div class="listingCardPrice" data-binding="data-value-cad={Price},innertext=DisplayPrice,title=ConvertedPrice" data-value-cad="$799,000" title="$799,000 ">$799,000 </div>
#  <div class="listingCardAddress" data-binding="innertext=Address">
#                          #2611 -29 SINGER CRT, Toronto, Ontario
#                      </div>
#  </div>
#  <div class="listingCardIconStrip" data-binding="FooterIcons,visible=ShowFooterIcons">
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">2 + 1</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bed-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bedrooms</div>
#  </div>
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">2</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bath-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bathrooms</div>
#  </div>
#  </div>
#  <div class="listingCardOfficeName" data-binding="innertext=OfficeNameAndType">HOMELIFE/BAYVIEW REALTY INC., Brokerage</div>
#  </div>
#  </div>
#  </a>,
#  <a class="blockLink listingDetailsLink" data-binding="href=DetailsURL" href="/real-estate/23993010/305-390-cherry-st-toronto-waterfront-communities-c8">
#  <div class="listingCardOuterBody">
#  <div class="listingCardImageCon">
#  <img alt="#305 -390 CHERRY ST, Toronto, Ontario " class="listingCardImage" data-binding="src=ImageURL,alt=Address" src="https://cdn.realtor.ca/listings/TS637793864594570000/reb82/medres/2/c5487682_1.jpg">
#  </img></div>
#  <div class="listingCardBody">
#  <div class="listingCardTopBody" data-binding="hidden=ListingNotFound">
#  <div class="listingCardMLS" style="display: none;">MLS<sup>®</sup>: <span data-binding="innertext=MLSNumber,title=MLSNumber" title="C5487682">C5487682</span></div>
#  <div class="listingCardPrice" data-binding="data-value-cad={Price},innertext=DisplayPrice,title=ConvertedPrice" data-value-cad="$638,000" title="$638,000 ">$638,000 </div>
#  <div class="listingCardAddress" data-binding="innertext=Address">
#                          #305 -390 CHERRY ST, Toronto, Ontario
#                      </div>
#  </div>
#  <div class="listingCardIconStrip" data-binding="FooterIcons,visible=ShowFooterIcons">
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">1</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bed-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bedrooms</div>
#  </div>
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">1</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bath-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bathrooms</div>
#  </div>
#  </div>
#  <div class="listingCardOfficeName" data-binding="innertext=OfficeNameAndType">RE/MAX WEST REALTY INC., Brokerage</div>
#  </div>
#  </div>
#  </a>,
#  <a class="blockLink listingDetailsLink" data-binding="href=DetailsURL" href="/real-estate/23992989/101-55-carscadden-dr-toronto-westminster-branson">
#  <div class="listingCardOuterBody">
#  <div class="listingCardImageCon">
#  <img alt="#101 -55 CARSCADDEN DR, Toronto, Ontario " class="listingCardImage" data-binding="src=ImageURL,alt=Address" src="https://cdn.realtor.ca/listings/TS637793862169730000/reb82/medres/6/c5487596_1.jpg">
#  </img></div>
#  <div class="listingCardBody">
#  <div class="listingCardTopBody" data-binding="hidden=ListingNotFound">
#  <div class="listingCardMLS" style="display: none;">MLS<sup>®</sup>: <span data-binding="innertext=MLSNumber,title=MLSNumber" title="C5487596">C5487596</span></div>
#  <div class="listingCardPrice" data-binding="data-value-cad={Price},innertext=DisplayPrice,title=ConvertedPrice" data-value-cad="$699,000" title="$699,000 ">$699,000 </div>
#  <div class="listingCardAddress" data-binding="innertext=Address">
#                          #101 -55 CARSCADDEN DR, Toronto, Ontario
#                      </div>
#  </div>
#  <div class="listingCardIconStrip" data-binding="FooterIcons,visible=ShowFooterIcons">
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">2</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bed-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bedrooms</div>
#  </div>
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">2</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bath-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bathrooms</div>
#  </div>
#  </div>
#  <div class="listingCardOfficeName" data-binding="innertext=OfficeNameAndType">SUTTON GROUP-ADMIRAL REALTY INC., Brokerage</div>
#  </div>
#  </div>
#  </a>,
#  <a class="blockLink listingDetailsLink" data-binding="href=DetailsURL" href="/real-estate/23992968/2504-185-roehampton-ave-toronto-mount-pleasant-west">
#  <div class="listingCardOuterBody">
#  <div class="listingCardImageCon">
#  <img alt="#2504 -185 ROEHAMPTON AVE, Toronto, Ontario " class="listingCardImage" data-binding="src=ImageURL,alt=Address" src="https://cdn.realtor.ca/listings/TS637793862100770000/reb82/medres/7/c5487527_1.jpg">
#  </img></div>
#  <div class="listingCardBody">
#  <div class="listingCardTopBody" data-binding="hidden=ListingNotFound">
#  <div class="listingCardMLS" style="display: none;">MLS<sup>®</sup>: <span data-binding="innertext=MLSNumber,title=MLSNumber" title="C5487527">C5487527</span></div>
#  <div class="listingCardPrice" data-binding="data-value-cad={Price},innertext=DisplayPrice,title=ConvertedPrice" data-value-cad="$749,000" title="$749,000 ">$749,000 </div>
#  <div class="listingCardAddress" data-binding="innertext=Address">
#                          #2504 -185 ROEHAMPTON AVE, Toronto, Ontario
#                      </div>
#  </div>
#  <div class="listingCardIconStrip" data-binding="FooterIcons,visible=ShowFooterIcons">
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">2</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bed-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bedrooms</div>
#  </div>
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">2</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bath-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bathrooms</div>
#  </div>
#  </div>
#  <div class="listingCardOfficeName" data-binding="innertext=OfficeNameAndType">HOUSESIGMA INC., Brokerage</div>
#  </div>
#  </div>
#  </a>,
#  <a class="blockLink listingDetailsLink" data-binding="href=DetailsURL" href="/real-estate/23992956/3201-575-bloor-st-e-toronto-cabbagetown-south-st-james-town">
#  <div class="listingCardOuterBody">
#  <div class="listingCardImageCon">
#  <img alt="#3201 -575 BLOOR ST E, Toronto, Ontario " class="listingCardImage" data-binding="src=ImageURL,alt=Address" src="https://cdn.realtor.ca/listings/TS637793862057970000/reb82/medres/2/c5487482_1.jpg">
#  </img></div>
#  <div class="listingCardBody">
#  <div class="listingCardTopBody" data-binding="hidden=ListingNotFound">
#  <div class="listingCardMLS" style="display: none;">MLS<sup>®</sup>: <span data-binding="innertext=MLSNumber,title=MLSNumber" title="C5487482">C5487482</span></div>
#  <div class="listingCardPrice" data-binding="data-value-cad={Price},innertext=DisplayPrice,title=ConvertedPrice" data-value-cad="$729,000" title="$729,000 ">$729,000 </div>
#  <div class="listingCardAddress" data-binding="innertext=Address">
#                          #3201 -575 BLOOR ST E, Toronto, Ontario
#                      </div>
#  </div>
#  <div class="listingCardIconStrip" data-binding="FooterIcons,visible=ShowFooterIcons">
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">1</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bed-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bedrooms</div>
#  </div>
#  <div class="listingCardIconCon">
#  <div class="listingCardIconTopCon">
#  <div class="listingCardIconNum" data-binding="innertext=NumberVal">1</div>
#  <div class="listingCardIcon" data-binding="innertext=IconHTML"><div class="propertyCardBedIcon"><img alt="" src="/images/common/icons/svg/bath-gray.svg"/></div></div>
#  </div>
#  <div class="listingCardIconText" data-binding="innertext=Label">Bathrooms</div>
#  </div>
#  </div>
#  <div class="listingCardOfficeName" data-binding="innertext=OfficeNameAndType">ROYAL LEPAGE SIGNATURE REALTY, Brokerage</div>
#  </div>
#  </div>
#  </a>]

# %%
sale = sales[0]
print(sale.prettify())
# Out:
# <a class="blockLink listingDetailsLink" data-binding="href=DetailsURL" href="/real-estate/23993307/708-75-st-nicholas-street-toronto">
#  <div class="listingCardOuterBody">
#   <div class="listingCardImageCon">
#    <img alt="708 75 St Nicholas Street, Toronto, Ontario " class="listingCardImage" data-binding="src=ImageURL,alt=Address" src="https://cdn.realtor.ca/listings/TS637793895698200000/reb14/medres/3/h4124943_1.jpg">
#    </img>
#   </div>
#   <div class="listingCardBody">
#    <div class="listingCardTopBody" data-binding="hidden=ListingNotFound">
#     <div class="listingCardMLS" style="display: none;">
#      MLS
#      <sup>
#       ®
#      </sup>
#      :
#      <span data-binding="innertext=MLSNumber,title=MLSNumber" title="H4124943">
#       H4124943
#      </span>
#     </div>
#     <div class="listingCardPrice" data-binding="data-value-cad={Price},innertext=DisplayPrice,title=ConvertedPrice" data-value-cad="$687,500" title="$687,500 ">
#      $687,500
#     </div>
#     <div class="listingCardAddress" data-binding="innertext=Address">
#      708 75 St Nicholas Street, Toronto, Ontario
#     </div>
#    </div>
#    <div class="listingCardIconStrip" data-binding="FooterIcons,visible=ShowFooterIcons">
#     <div class="listingCardIconCon">
#      <div class="listingCardIconTopCon">
#       <div class="listingCardIconNum" data-binding="innertext=NumberVal">
#        1
#       </div>
#       <div class="listingCardIcon" data-binding="innertext=IconHTML">
#        <div class="propertyCardBedIcon">
#         <img alt="" src="/images/common/icons/svg/bed-gray.svg"/>
#        </div>
#       </div>
#      </div>
#      <div class="listingCardIconText" data-binding="innertext=Label">
#       Bedrooms
#      </div>
#     </div>
#     <div class="listingCardIconCon">
#      <div class="listingCardIconTopCon">
#       <div class="listingCardIconNum" data-binding="innertext=NumberVal">
#        1
#       </div>
#       <div class="listingCardIcon" data-binding="innertext=IconHTML">
#        <div class="propertyCardBedIcon">
#         <img alt="" src="/images/common/icons/svg/bath-gray.svg"/>
#        </div>
#       </div>
#      </div>
#      <div class="listingCardIconText" data-binding="innertext=Label">
#       Bathrooms
#      </div>
#     </div>
#    </div>
#    <div class="listingCardOfficeName" data-binding="innertext=OfficeNameAndType">
#     RE/MAX Real Estate Centre Inc.
#    </div>
#   </div>
#  </div>
# </a>

# %%
# extract url for each sale
link = sale.attrs['href']
link
# Out:
# '/real-estate/23993307/708-75-st-nicholas-street-toronto'

# %% [markdown]
# ### Extract sale info for one building

# %%
response1=requests.get('https://www.realtor.ca/' + link,headers=headers)

sale_soup=BeautifulSoup(response1.content)
sale_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head><script async="" src="/dnight-Exit-shall-Braith-Then-why-vponst-is-proc"></script><meta charset="utf-8"/><meta content="#D0191D" name="theme-color"/><meta content="width=device-width" name="viewport"/><meta content="notranslate" name="google"/><meta content="NO-CACHE" http-equiv="CACHE-CONTROL"/><meta content="NO-CACHE" http-equiv="PRAGMA"/><meta content="NOARCHIVE" name="GOOGLEBOT"/><meta content="telephone=no" name="format-detection"/><meta content="a2430a87e639e6cf0f00273171d97103" name="shareaholic:site_id"/><link as="style" href="/bundles/css/desktop/page/listing" rel="prefetch"/>
# <link as="style" href="/bundles/css/desktop/page/map/locallogic" rel="prefetch"/><link as="script" href="/bundles/js/desktop/page/listing" rel="prefetch"/>
# <link as="script" href="/bundles/js/desktop/page/map" rel="prefetch"/>
# <link as="script" href="/bundles/js/desktop/page/index" rel="prefetch"/>
# <link href="https://www.realtor.ca/real-estate/23993307/708-75-st-nicholas-street-toronto" hreflang="en" rel="alternate">
# <link href="https://www.realtor.ca/immobilier/23993307/708-75-st-nicholas-street-toronto" hreflang="fr" rel="alternate">
# <link href="https://www.realtor.ca/real-estate/23993307/708-75-st-nicholas-street-toronto" rel="canonical">
# <meta content="1635916343293952" property="fb:app_id"/><meta content="https://www.realtor.ca/real-estate/23993307/708-75-st-nicholas-street-toronto" property="og:url"/><meta content="Check out this listing" property="og:title"/><meta content="https://cdn.realtor.ca/listing/TS637793895698200000/reb14/highres/3/h4124943_1.jpg?w=512&amp;h=256&amp;ts=1" property="og:image"/><meta content="https://cdn.realtor.ca/listing/TS637793895698200000/reb14/highres/3/h4124943_1.jpg?w=512&amp;h=256&amp;ts=1" property="og:image:secure_url"/><meta content="512" property="og:image:width"/><meta content="256" property="og:image:height"/><meta content="708 75 St Nicholas Street, Toronto, Ontario   M4Y0A5" property="og:description"/><meta content="website" property="og:type"/><meta content="summary" name="twitter:card"/><meta content="Check out this listing" name="twitter:title"/><meta content="708 75 St Nicholas Street, Toronto, Ontario   M4Y0A5" name="twitter:description"/><meta content="https://cdn.realtor.ca/listing/TS637793895698200000/reb14/highres/3/h4124943_1.jpg" name="twitter:image"/><title>
# 	For sale: 708 75 St Nicholas Street, Toronto, Ontario M4Y0A5 - H4124943 | REALTOR.ca
# </title>
# <!-- FavIcon and browser tile defaults (begin)-->
# <link href="/images/common/icons/browser/favicon.ico?v=3" id="favicon" rel="shortcut icon" type="image/x-icon"><link href="/images/common/icons/browser/favicon.png?v=3" rel="icon" type="image/png"><link href="/images/common/icons/browser/favicon-32.png?v=3" rel="icon" sizes="32x32" type="image/png"/><link href="/images/common/icons/browser/favicon-64.png?v=3" rel="icon" sizes="64x64" type="image/png"/><link href="/images/common/icons/browser/favicon-96.png?v=3" rel="icon" sizes="96x96" type="image/png"/><link href="/images/common/icons/browser/favicon-196.png?v=3" rel="icon" sizes="196x196" type="image/png"/><link href="/images/common/icons/browser/apple-touch-icon-60x60.png?v=3" rel="apple-touch-icon" sizes="60x60"/><link href="/images/common/icons/browser/apple-touch-icon-76x76.png?v=3" rel="apple-touch-icon" sizes="76x76"/><link href="/images/common/icons/browser/apple-touch-icon-114x114.png?v=3" rel="apple-touch-icon" sizes="114x114"/><link href="/images/common/icons/browser/apple-touch-icon-120x120.png?v=3" rel="apple-touch-icon" sizes="120x120"/><link href="/images/common/icons/browser/apple-touch-icon-120x120-precomposed.png?v=3" rel="apple-touch-icon" sizes="120x120"/><link href="/images/common/icons/browser/apple-touch-icon-144x144.png?v=3" rel="apple-touch-icon" sizes="144x144"/><link href="/images/common/icons/browser/apple-touch-icon-152x152.png?v=3" rel="apple-touch-icon" sizes="152x152"/><link href="/images/common/icons/browser/apple-touch-icon-180x180.png?v=3" rel="apple-touch-icon" sizes="180x180"/><meta content="/images/common/icons/browser/favicon-144.png?v=3" name="msapplication-TileImage"/><meta content="#FFFFFF" name="msapplication-TileColor"/>
# <!-- FavIcon and browser tile defaults (end) -->
# <!-- Script for Azure ApplicationInsights -->
# <link crossorigin="" href="//az416426.vo.msecnd.net" rel="preconnect"/>
# <script type="text/javascript">var appInsights = window.appInsights || function (config) { function r(config) { t[config] = function () { var i = arguments; t.queue.push(function () { t[config].apply(t, i) }) } } var t = { config: config }, u = document, e = window, o = "script", s = u.createElement(o), i, f; for (s.src = config.url || "//az416426.vo.msecnd.net/scripts/a/ai.0.js", u.getElementsByTagName(o)[0].parentNode.appendChild(s), t.cookie = u.cookie, t.queue = [], i = ["Event", "Exception", "Metric", "PageView", "Trace"]; i.length;)r("track" + i.pop()); return r("setAuthenticatedUserContext"), r("clearAuthenticatedUserContext"), config.disableExceptionTracking || (i = "onerror", r("_" + i), f = e[i], e[i] = function (config, r, u, e, o) { var s = f && f(config, r, u, e, o); return s !== !0 && t["_" + i](config, r, u, e, o), s }), t }({ instrumentationKey:"33b05b9d-84a5-4f99-829c-689a27ea5c4d" }); window.appInsights = appInsights; appInsights.trackPageView();</script>
# <link href="/manifest.json" rel="manifest"/><link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/><link crossorigin="" href="https://cdn.realtor.ca" rel="preconnect"/><link href="https://fonts.googleapis.com/css?family=Source+Sans+Pro" rel="stylesheet"/>
# <script src="/Scripts/Desktop/Translations.aspx?ver=1.0.8066.37080&amp;k=1&amp;lang=en"></script>
# <link href="/bundles/css/desktop?v=hWmn3vfeFHY7pv-nmtGpEqWJr2iPii7mExW5DxkUCIo1&amp;ver=1.0.8066.37080&amp;k=1" rel="stylesheet" type="text/css"/>
# <script src="/bundles/js/desktop?v=LUSaQ5EH_4B1K2VkdE8wiugVWTKYiV75lzFDM08sgXI1&amp;ver=1.0.8066.37080&amp;k=1" type="text/javascript"></script>
# <script defer="" src="/bundles/gigya?v=wUkF9VlNvELo_67CuLXl2Xd1h6kZ1kh6xv8nq_TGcJM1&amp;ver=1.0.8066.37080&amp;k=1" type="text/javascript"></script>
# <link crossorigin="" href="//www.google.com" rel="preconnect"/>
# <script async="" defer="" src="//www.google.com/recaptcha/api.js?render=explicit&amp;onload=captchaCallback&amp;hl=en" type="text/javascript"></script>
# <script src="/Scripts/ServerScript.aspx?ver=1.0.8066.37080&amp;k=1&amp;lang=en&amp;d=Desktop"></script>
# <script> callAfterDOMLoaded(() => { $(window).load(function(){  Utilities.loadScript('/scripts/foresee/foresee-ACS-Live.js');}); });</script>
# <!--
#         Preserve the Document.Referer before Google Tag Manager since
#         its used heavily in the Analytics part...
#     -->
# <script>
#         (function () {
#             try {
#                 if (typeof sessionStorage !== 'undefined') {
#                     var distilReferrer = sessionStorage.getItem('distil_referrer');
#                     if (distilReferrer) {
#                         Object.defineProperty(document, "referrer", {
#                             get: function () { return distilReferrer; },
#                         });
#                         sessionStorage.removeItem("distil_referrer");
#                     }
#                 }
#             } catch (e) { }
#         })()
#     </script>
# <!-- START OF BASE DATALAYER -->
# <script id="GTMDataLayerCode" type="text/javascript">
#                          window.dataLayer = window.dataLayer || [];
#                         dataLayer.push({
#                            event: 'propertyDetailsLoaded',
#                            pagePath: (location.pathname + (location.search || '')),
#                            pageTitle: document.title,
#                            visitor: {
#                                loggedIn: 'No',
#                                userId: '',
#                                favouriteCountValue: '0',
#                                saveSearchCountValue: '0'
#                            },
#                            site: {
#                                language: 'EN'
#                            },
#                             property: {
#                                 propertyID: '23993307',
#                                 listingID: 'H4124943',
#                                 propertyType: 'Single Family',
#                                 price: '687500.00',
#                                 leasePrice: '',
#                                 buildingType: 'Apartment',
#                                 neighbourhood: '',
#                                 bathrooms: '1',
#                                 bedrooms: '1',
#                                 communityFeatures: '',
#                                 nearbyAmenities: 'Hospital, Public Transit, Schools',
#                                 storeys: '1',
#                                 walkscore: '',
#                                 transitscore: '',
#                                 machineryIncluded: '',
#                                 rentalEquipment: 'None',
#                                 parkingType: 'Underground',
#                                 majorBusinessType: '',
#                                 minorBusinessType: '',
#                                 totalUnits: '',
#                                 landSize: '0 x 0',
#                                 zoningType:  '',
#                                 interiorFloorSpace: '596 sqft',
#                                 exteriorBuildingSize:  '596 sqft',
#                                 franchise: '',
#                                 buildingAmenities: 'Exercise Centre, Party Room',
#                                 buildingStyle: '',
#                                 basementDevelopment: '',
#                                 notificationUpdate: 'no',
#                                 anchor: '',
#                                 retailStorefront: '',
#                                 clearCeilingHeight: '',
#                                 hasphoto: 'yes' ,
#                                 photos: '30' ,
#                                 multimediaFeatures: 'Video,FloorPlan',
#                                 listingVideoType: 'iGuide',
#                                 city: 'Toronto',
#                                 province: 'Ontario',
#                                 soldData: 'no',
#                                 hasAlternateFeatureSheet: 'yes',
#                                 hasOpenHouse: 'no',
#                                 hasVirtualOpenHouse: 'no',
#                                 hasCMHCFTHBBanner: 'yes',
#                                 hasTDpreApprovalIcon: 'no',
#                                 hasActiveVirtualOpenHouse: 'no'
#                             }
#                         });
#                     </script>
# <!-- END OF BASE DATALAYER -->
# <!-- Page-hiding snippet (recommended)  -->
# <!-- END OF Page-hiding snippet (recommended)  -->
# <!-- Modified Analytics tracking code with Optimize plugin -->
# <!-- End of Modified Analytics tracking code with Optimize plugin -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                         'https://www.googletagmanager.com/gtm.js?id='+i+dl; f.parentNode.insertBefore(j,f);
#                         })(window,document,'script','dataLayer','GTM-WXXF7GN');</script>
# <!-- End Google Tag Manager -->
# <!-- Analytics -->
# <script type="text/javascript">function logAnalytics(listingId,eventType){}</script>
# <!-- End Analytics -->
# <link as="font" crossorigin="" href="/fonts/FontAwesome/fonts/fontawesome-webfont.woff2?v=4.7.0" rel="preload" type="font/woff2"/>
# <script>
#         var page;
#         Utilities.termOfUseRedirectExec();
#         MasterPages.Desktop.initialize();
#         $(document).ready(function () {
#             if (ApplicationState.UserIsSignedIn == false) {
#                 GigyaInit.setupUrlForwarding();
#             }
#             page = new MasterPages.Desktop(null, null,true);
#         });
#     </script>
# <style>
#         @media print {
#             #topRedStrip {
#                 margin: 0 30px 0 30px !important;
#                 width: calc(100% - 60px) !important;
#             }
#         }
#
#         #topRedStrip {
#             background-color: #D0191D;
#             /*position: absolute;
#             top: 0;*/
#             /*height: 60px;*/
#             height: 56px;
#             width: 100%;
#             z-index: -1;
#         }
#
#         #mainCon {
#             /*max-width: 1440px;*/
#             max-width: 1360px;
#             min-width: 1260px;
#             margin: auto;
#             margin-top: -56px;
#         }
#     </style>
# <meta content="Single Family (condominium) apartment 1 bedrooms, 1 bathrooms,708 75 st nicholas street toronto, ontario, for sale $687,500 " name="description"/><meta content="Single Family 1 Bedrooms" name="keywords"/></link></link></link></link></link></head>
# <body>
# <!-- Google Tag Manager(noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WXXF7GN" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager(noscript) -->
# <!-- No auto-complete off = chrome RANDOMLY autofilling input controls -->
# <form action="./708-75-st-nicholas-street-toronto" autocomplete="off" id="form1" method="post">
# <div class="aspNetHidden">
# <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="/XCOIxEvJp2+mP68u91jydcGdwhhg4kI8SyJ2pC973bubfayyXNrtZcaHvvOtBuDa/wP2mXa+2tK1IrnYGyb/YMvWwI="/>
# </div>
# <div class="aspNetHidden">
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="5B391DF9"/>
# </div>
# <span class="ControlBaseWrapper" id="TOUMessageCtrl" style="">
# <style>
#     #TOUMsgInnerCon a{
#         text-decoration: none;
#         font-weight: bolder;
#     }
#     #TOUMsgCon #TOUdismissBtn{
#         margin-left:100px;
#         font-weight: bolder;
#     }
#     #TOUMsgCon .blueRoundedBtn {
#         color: white;
#         font-size:18px;
#     }
#     #TOUMsgCon {
#         width: 100%;
#         padding: 15px 10px;
#         background-color: #4f495a;
#         text-align: center;
#         font-size: 18px;
#         display: -webkit-box;
#         display: -ms-flexbox;
#         display: flex;
#         -webkit-box-sizing: border-box;
#         box-sizing: border-box;
#         -webkit-box-align: center;
#         -ms-flex-align: center;
#         align-items: center;
#         position: fixed;
#         bottom: 0px;
#         justify-content: center;
#         z-index: 335;
#     }
#
#     #TOUMsgInnerCon {
#         color: white;
#         display: -webkit-box;
#         display: -moz-box;
#         display: -ms-flexbox;
#         display: -webkit-flex;
#         display: flex;
#         -ms-flex-align: center;
#         justify-content: center;
#         align-items: center;
#        -webkit-box-sizing: border-box;
#         box-sizing: border-box;
#     }
# </style>
# <div class="noPrint" id="TOUMsgCon">
# <div id="TOUMsgInnerCon">
# <div>By using our site, you agree to our <a href="/terms-of-use" id="TouBannerTouLink" style="font-weight: bold;">Terms of Use</a> and <a href="/privacy-policy" id="TouBannerPrivacyPolicyLink" style="font-weight: bold;">Privacy Policy</a>.</div><div><a class="lnkTOUDismiss blueRoundedBtn btn" href="#" id="TOUdismissBtn">Dismiss</a></div>
# </div>
# </div>
# <script>
#     var TOUMessage = new Controls.Desktop.TOUMessage(null, 'TOUMessageCtrl');
# </script>
# </span>
# <div id="topRedStrip"></div>
# <div class="loadingBar" id="loadingBar" style="display: none;"></div>
# <div id="mainCon">
# <span class="ControlBaseWrapper" id="Header" style="">
# <header id="header">
# <div id="headerLeft">
# <a href="/">
# <img alt="REALTOR.ca logo" src="/images/logo.svg" style="height: 56px; width: 159px; vertical-align: middle; margin-left: -10px;"/></a>
# <div class="noPrint" id="cmsPreviewCont">
# <div id="cmsPreviewInnerCont">
# </div>
# </div>
# </div>
# <div class="noPrint" id="headerRight">
# <div class="currencyCon">
# <div id="lnkCurrency">
# <div class="currencyInnerCon">
# <div class="headerCurrencyLabel">
# <span id="headerCurrencyDisplayName">CAD</span>
# <img alt="" class="dropdownIcon" src="/images/common/icons/svg/arrow-down-white2.svg" style="height:24px; width: 24px;">
# </img></div>
# </div>
# </div>
# </div>
# <div style="margin-left: 70px;">
# <div class="profileMenuLink" id="lnkProfileMenuSignin">
# <img alt="" id="headerSignInImg" src="/images/common/icons/svg/profile-icon.svg" style="height: 32px; width: 32px;"/>
# <div class="profileMenuText" id="headerSignInText">Sign In</div>
# </div>
# </div>
# <div class="profileMenuHeaderCon">
# <div class="profileMenuLink" id="lnkProfileMenuMyAccount" style="display: none;">
# <img alt="" id="headerMyAccountImg" src="/images/common/icons/svg/profile-icon.svg" style="height: 32px; width: 32px;"/>
# <div class="profileMenuText" id="headerMyAccountText"></div>
# </div>
# <div class="hide" id="headerProfileDropdown">
# <a class="m_hdr_dropdown_link" href="/my-account/account-information" id="lnkHeaderAccountInformation">
# <div class="m_hdr_dropdown_menu">My Account</div>
# </a>
# <a class="m_hdr_dropdown_link" href="/my-settings/search-criteria" id="lnkHeaderSearchCriteria">
# <div class="m_hdr_dropdown_menu">My Settings</div>
# </a>
# <a class="m_hdr_dropdown_link" href="/my-notification-preferences/preferences" id="lnkHeaderNotifications">
# <div class="m_hdr_dropdown_menu">My Notification  Settings</div>
# </a>
# <a class="m_hdr_dropdown_link" href="#" id="lnkHeaderLogout">
# <div class="m_hdr_dropdown_menu">Sign Out</div>
# </a>
# </div>
# </div>
# <div style="margin-left: 50px;">
# <span class="ControlBaseWrapper" id="langToggle" style="">
# <div class="toggleSwitchCon">
# <div class="toggleSwitchInnerCon">
# <a class="toggleOption selected" data-value="1" href="/real-estate/23993307/708-75-st-nicholas-street-toronto">EN</a>
# <a class="toggleOption" data-value="2" href="/immobilier/23993307/708-75-st-nicholas-street-toronto">FR</a>
# <div class="toggleSelector" style="width: 50%; left: 0%;"></div>
# </div>
# </div>
# <script>
#     var toggle = new Controls.Desktop.Toggle(null, 'langToggle');
# </script>
# </span>
# </div>
# </div>
# </header>
# <script>
#     var Header = new Controls.Desktop.Header(null, 'Header');
# </script>
# </span>
# <span class="ControlBaseWrapper" id="ctl35" style="">
# <div class="noPrint" id="headerMenu">
# <div class="headerMenuItem"><a href="/map">Find a Home</a></div>
# <div class="headerMenuItem">
# <div class="headerMenuItemText">
#
#     Find a REALTOR<sup>®</sup>
# <img alt="" class="dropdownIcon" src="/images/common/icons/svg/arrowdown.svg" style="height: 8px; width: 15px;"/>
# </div>
# <div class="topMenuDropdownContent hide">
# <a class="topMenuDropdownItem" href="/realtors/location">Location</a>
# <a class="topMenuDropdownItem" href="/realtors/name">Name</a>
# <a class="topMenuDropdownItem" href="/brokerage">Office</a>
# </div>
# </div>
# <div class="headerMenuItem">
# <div class="headerMenuItemText">
#             Mortgage Calculators
#             <img alt="" class="dropdownIcon" src="/images/common/icons/svg/arrowdown.svg" style="height: 8px; width: 15px;"/>
# </div>
# <div class="topMenuDropdownContent hide">
# <a class="topMenuDropdownItem" href="/calculator/mortgage-calculator">Payment Calculator</a>
# <a class="topMenuDropdownItem" href="/calculator/land-transfer-tax">Land Transfer Tax Calculator</a>
# <a class="topMenuDropdownItem" href="/calculator/affordability">Affordability Calculator</a>
# </div>
# </div>
# <div class="headerMenuItem">
# <div style="margin: auto;">
# <div class="headerMenuItemText">
#                 Ideas &amp; How-to
#                 <img alt="" class="dropdownIcon" src="/images/common/icons/svg/arrowdown.svg" style="height: 8px; width: 15px;"/>
# </div>
# <div class="topMenuDropdownContent hide">
# <a class="topMenuDropdownItem" href="/blog">Living Room Blog</a>
# <a class="topMenuDropdownItem" href="/tips-for-buyers">Tips for Buyers</a>
# <a class="topMenuDropdownItem" href="/tips-for-sellers">Tips for Sellers</a>
# <a class="topMenuDropdownItem" href="/commercial-resources">Commercial Resources</a>
# </div>
# </div>
# </div>
# <div class="headerMenuItem">
# <a class="smallCountCircleCon headerMenuActionIcon" href="/my-daily-notifications" id="lnkTopMenuNotifications">
# <img alt="My Notifications" src="/images/common/icons/svg/bell.svg" style="height: 32px;"/>
# <div class="smallCountCircleRight" id="topMenuNotificationCountNum" style="display:none;">0</div>
# </a>
# <a class="smallCountCircleCon headerMenuActionIcon" href="/my-saved-searches" id="lnkTopMenuSavedSearches">
# <img alt="My Saved Searches" src="/images/common/icons/svg/searches.svg" style="height: 30px;"/>
# <div class="smallCountCircleRight" id="topMenuSavedSearchCountNum" style="display:none;">0</div>
# </a>
# <a class="smallCountCircleCon headerMenuActionIcon" href="/my-favourites" id="lnkTopMenuFavourites">
# <img alt="My Favourites" src="/images/common/icons/svg/heart.svg" style="height: 32px;"/>
# <div class="smallCountCircleRight" id="topMenuFavCountNum" style="display:none;">0</div>
# </a>
# </div>
# </div>
# <script>
#     var TopMenu = new Controls.Desktop.TopMenu(null, 'ctl35');
# </script>
# </span>
# <!-- Sticky buttons place holder -->
# <div id="sticky_buttons"></div>
# <!-- Gigya -->
# <script>
#                 $(document).ready(function (e) {
#
#                     var s = document.createElement("script");
#                     s.type = "text/javascript";
#                     s.src = "//cdns.gigya.com/JS/gigya.js?apiKey=3_mrQiIl6ov44s2X3j6NGWVZ9SDDtplqV7WgdcyEpGYnYxl7ygDWPQHqQqtpSiUfko";
#                     s.innerHTML = '{ enabledProviders: "facebook,twitter,googleplus,linkedin,apple", lang: "en", bypassCookiePolicy: "always" }';
#                     s.onload = function (e) {
#                         gigyaAPIJSLoaded();
#                     };
#                     document.getElementsByTagName("head")[0].appendChild(s);
#                 });
#             </script>
# <div id="BodyContenCon">
# <script class="PagePreRenderScriptClass" id="PagePreRenderScriptBlock_40147311">Events.Fire('PagePreRender','pages_desktop_listing_ascx');</script><script>ApplicationState.CurrentRoutingRecordKey='listing-details';</script><span class="ControlBaseWrapper" id="MainContent_ctl00_ctl00" style="">
# <style>
#     /** (virtually?) always have scroll bars, reduce layout shift */
#     html {
#         overflow-y: scroll;
#     }
#
#     /** Reduce layout shift*/
#     #similarListingsCon .swiper-wrapper {
#         min-height: 500px
#     }
#
#     .homeFirstTimeBuyerIcon {
#         padding-right: 7px;
#         display: table-cell;
#         width: 16px;
#         font-size: 1rem;
#         vertical-align: middle;
#         padding-top: 4px;
#     }
#
#     .listingHomeFirstTimeBuyerContainer {
#         background-color: #4f495a;
#         color: white;
#         padding: 8px 15px 8px 15px;
#         margin-left: -16px;
#         margin-right: -16px;
#         margin-top: 15px;
#         margin-bottom: -15px;
#     }
#
#     .listingHomeFirstTimeBuyerInnerContainer {
#         display: -webkit-box;
#         display: -webkit-flex;
#         display: -ms-flexbox;
#         display: flex;
#         justify-content: space-between;
#         align-items: center;
#     }
#
#     #homeFirstTimeBuyerBtnLink {
#         font-size: 1rem;
#         font-weight: bold;
#         padding: 8px 25px;
#     }
#
#     .homeFirstTimeBuyerText {
#         line-height: 16px;
#         vertical-align: text-bottom;
#     }
#
#     #homeFirstTimeBuyerBtnLink-inner {
#         text-decoration: none;
#         color: #4f495a;
#         display: table;
#         margin-left: auto;
#         margin-right: auto;
#     }
#
#     .homeFirstTimeBuyerBtnText {
#         display: table-cell;
#     }
#
#     #LHLegalDisclaimer {
#         font-size: 0.7em;
#         padding: 10px 10px;
#         margin: auto;
#         text-align: center;
#         color: #828282;
#     }
#
#     #historyDetailSection {
#         display: none;
#     }
#
#     table#tableHistoryDetail, #tableHistoryDetail td, #tableHistoryDetail th {
#         border: 1px solid #ddd;
#         text-align: left;
#     }
#
#     table#tableHistoryDetail {
#         table-layout: fixed;
#         border-collapse: collapse;
#         width: 100%;
#     }
#
#     #tableHistoryDetail th, #tableHistoryDetail td {
#         padding: 5px;
#         /*overflow-wrap: break-word;*/
#     }
#
#     #propertyDetailsRealtorsCon .realtorCardCon,
#     #propertyDetailsRealtorsCon .officeCardCon {
#         display: block; /* Stops odd extra gap between cards*/
#     }
#
#     #propertyDetailsRealtorsCon .officeCardLogo {
#         max-width: 85px;
#     }
#
#     #pnlImageCarousel .dialogCloseX {
#         padding: 0px;
#     }
#
#     .rsArrowIcn {
#         border: 1px solid #ccc !important;
#     }
#
#     .m_ryl_sld .d_hdr {
#         background-color: #e0e0da !important;
#     }
#
#     .rsDefault .rsThumb.rsNavSelected img {
#         border-top: 4px solid #23A1C0;
#     }
#
#     .rsDefault, .rsDefault .rsOverflow, .rsDefault .rsSlide, .rsDefault .rsVideoFrameHolder, .rsDefault .rsThumbs {
#         background-color: white !important;
#     }
#
#         .rsDefault .rsThumbsHor {
#             background-color: #F2F2F2 !important;
#             border-top: 1px solid #cdcdcd;
#             padding-top: 15px;
#         }
#
#     .realtorCardCon {
#         margin-bottom: 15px;
#     }
#
#     .officeCardCon {
#         margin-bottom: 15px;
#     }
#
#
#     #listingBackBtnCon .whiteButtonLeftIcon {
#         margin-left: 0px;
#     }
#
#     .whiteButtonLeftIcon {
#         margin-left: 7px;
#     }
#
#
#     #vm_btnDialogClose {
#         padding: 10px 10px 6px 10px;
#         cursor: pointer;
#     }
#
#     .d_hdr {
#         padding: 20px 100px 0px 20px;
#         border-bottom: 1px solid #908d99;
#     }
#
#         .d_hdr #btnDialogClose {
#             cursor: pointer;
#             border: none;
#         }
#
#         .d_hdr div,
#         .d_hdr a {
#             position: absolute;
#             right: 0;
#             top: 0;
#         }
#
#             .d_hdr div span,
#             .d_hdr a span {
#                 line-height: 17px;
#                 vertical-align: middle;
#                 text-decoration: underline;
#             }
#
#     .m_ryl_sld_hdr_close {
#         width: 40px;
#         position: absolute !important;
#         display: block;
#     }
#
#     .b_base {
#         margin: 0;
#         padding: 10px 10px 6px 10px;
#         display: inline-block;
#         color: #fff !important;
#         background: silver;
#         text-align: center;
#         font-size: 1em !important;
#         font-weight: normal !important;
#         border: 0;
#         cursor: pointer;
#         min-width: 95px;
#     }
#
#     .b_close {
#         min-width: inherit !important;
#     }
#
#     .b_low {
#         background: #e0e0da;
#         border-bottom: 2px solid #9b9584;
#         color: #221b33 !important;
#     }
#
#     .b_fit {
#         width: auto;
#     }
#
#     .rsCloseVideoBtn {
#         display: none;
#     }
#
#
#     #vm_royalslider-def .rsNav {
#         display: none;
#     }
#
#     .rsVideoContainer {
#         z-index: 335 !important;
#     }
#
#     .rsCloseVideoBtn {
#         display: none;
#     }
#
#     .m_ryl_sld {
#         max-width: 1050px;
#         max-height: 950px;
#         background-color: white !important;
#         width: 85% !important;
#         height: 85% !important;
#         display: -webkit-inline-flex;
#         display: -ms-inline-flexbox;
#         display: inline-flex;
#         -webkit-flex-flow: column;
#         -ms-flex-direction: column;
#         flex-direction: column;
#         min-width: 200px;
#         /*
# 	        Use of animation over animation-name: HUGE IOS bug -container implementing it
# 	        suddenly becomes relative position and fixed position elements under it becomes position absolute...
#         */
#         -webkit-animation: fadeIn 0.5s;
#         animation: fadeIn 0.5s;
#     }
#
#         .m_ryl_sld .d_hdr {
#             width: 100%;
#             min-height: 43px;
#             padding: 0;
#             overflow: hidden;
#             background: #f2f2ed;
#             color: #221b33;
#             border: 0;
#             font-size: 1.125em;
#             background: #4f495a;
#             margin-bottom: 0px;
#         }
#
#     #listingCalculatorsDisclaimerCon {
#         margin: 10px 10px 10px 10px;
#         font-size: 0.7em;
#         text-align: center;
#         color: #828282;
#     }
#
#     #propertyDetailsNotePrintCon {
#         display: none;
#         margin: 10px;
#         border: 1px solid #CCCCCC;
#     }
#
#     .notePrintTitle, .noteSharedTitle {
#         font-weight: bold;
#     }
#     /*.locallogic-score-row{ padding-top: 15px;}
#         .locallogic-section-container{ padding-bottom: 15px;}*/
#     .propertyDetailsAddCalendarIcon {
#         font-size: 20px;
#         /* color: #23A1C0;*/
#         display: table-cell;
#         padding-right: 10px;
#     }
#
#     .propertyDetailsAddCalendar {
#         /*color: #23A1C0;*/
#         display: table-cell;
#         vertical-align: -webkit-baseline-middle;
#     }
#
#     .liveStreamConLink {
#         color: inherit;
#         text-decoration: inherit;
#         -webkit-box-flex: 1;
#         -ms-flex: 1;
#         flex: 1;
#         display: inherit;
#     }
#
#     #listingDetailsTopInnerCon {
#         min-height: 56px; /* Reduce layout shift */
#     }
#
#
#     .propertyCovidOpenHouseMessageCon {
#         display: table;
#         width: 100%;
#         margin-bottom: 15px;
#     }
#
#     .listingDetailsCovidOpenHouse {
#         padding: 8px;
#         background: #ffe8a8;
#         color: #7f7f7f;
#         font-size: 0.95em;
#         display: flex;
#         display: -webkit-flex;
#         display: -moz-flex;
#         display: -ms-flex;
#     }
#
#         .listingDetailsCovidOpenHouse .fa-exclamation-circle {
#             color: #c89c1e;
#             padding-right: 5px;
#             font-size: 1.4em;
#             vertical-align: middle;
#         }
#
#     .listingDetailsCovidOpenHouseText {
#         vertical-align: middle;
#     }
#
#     .propertyCovidOpenHouseMessageLeft {
#         display: table-cell;
#         vertical-align: top;
#         padding-right: 15px;
#     }
#
#     .propertyCovidOpenHouseMessageRight {
#         display: table-cell;
#         width: 330px;
#         vertical-align: top;
#     }
#
#     .swiperPlayBtnVideo {
#         -webkit-tap-highlight-color: rgba(0,0,0,0.3);
#         width: 40px;
#         height: 40px;
#         margin-left: 20px;
#         margin-top: 20px;
#         cursor: pointer;
#     }
#
#     .swiperPlayBtnIconVideo {
#         width: 40px;
#         display: block;
#         height: 40px;
#         -webkit-border-radius: 4px;
#         border-radius: 4px;
#         background: url(/images/common/icons/svg/play-gray.svg);
#         background-color: white;
#     }
#
#     .swiperPlayBtnVideo:hover .swiperPlayBtnIconVideo,
#     .swiperPlayBtnVideo .swiperPlayBtnIconVideo.hovered {
#         background: url(/images/common/icons/svg/play-red.svg);
#         background-color: white;
#     }
#
#     #propertyVirtualVideosCon {
#         background-color: white;
#         display: -webkit-box;
#         display: -webkit-flex;
#         display: -ms-flexbox;
#         display: flex;
#         justify-content: center;
#         align-items: center;
#         padding: 7px 0 7px 0;
#     }
#
#     #swiper-videos.swiper-container-horizontal .swiper-pagination-bullets.swiper-pagination-bullets-dynamic .swiper-pagination-bullet {
#         transition: 200ms transform, 200ms left;
#     }
#
#     #swiper-videos.swiper-container-horizontal .swiper-pagination-bullets .swiper-pagination-bullet {
#         margin: 0 4px;
#     }
#
#     #swiper-videos.swiper-container-horizontal .swiper-pagination-bullets.swiper-pagination-bullets-dynamic {
#         white-space: nowrap;
#     }
#
#     #swiper-videos-pagination .swiper-pagination-bullet:not(.swiper-pagination-bullet-active) {
#         opacity: 1 !important;
#         background: #aeaeae !important;
#     }
#
#     #swiper-videos-pagination .swiper-pagination-bullet-active {
#         opacity: 1 !important;
#         --swiper-theme-color: #246a7c;
#     }
#
#     #swiper-videos-pagination {
#         position: relative !important;
#         bottom: 0px !important;
#         left: 0px;
#         transform: initial;
#         height: 8px;
#         margin-top: 15px;
#         margin-bottom: 15px;
#         margin-left: 15px;
#         margin-right: 15px;
#     }
#
#     #swiper-videos.swiperFullscreen .videoThumbnail {
#         max-width: 710px;
#     }
#
#     #swiper-videos.swiperFullscreen .swiper-slide {
#         height: 100%;
#     }
#
#     #swiper-videos.swiperFullscreen {
#         position: fixed !important;
#         height: auto !important;
#         width: auto !important;
#         margin: 0 !important;
#         padding: 0 !important;
#         z-index: 2147483647 !important;
#         top: 0 !important;
#         left: 0 !important;
#         bottom: 0 !important;
#         right: 0 !important;
#         background: black;
#         color: #fff;
#         width: 100%;
#         -webkit-box-orient: vertical;
#         -webkit-box-direction: normal;
#         -webkit-flex-flow: column;
#         -ms-flex-direction: column;
#         flex-direction: column;
#         display: -webkit-inline-box;
#         display: -webkit-inline-flex;
#         display: -ms-inline-flexbox;
#         display: inline-flex;
#         -webkit-box-flex: 1;
#         -webkit-flex: 1;
#         -ms-flex: 1;
#         flex: 1;
#         max-width: none;
#     }
#
#     #swiper-videos .swiper-slide {
#         text-align: center;
#         /* Center slide text vertically */
#         display: flex;
#         justify-content: center;
#         align-items: center;
#         overflow: hidden;
#         height: 300px;
#     }
#
#         #swiper-videos .swiper-slide img {
#             position: absolute;
#             max-width: 100%;
#             z-index: 2;
#             cursor: pointer;
#         }
#
#     .swiper-close-btn-container {
#         display: none;
#     }
#
#     .swiper-container.swiperFullscreen .swiper-close-btn-container {
#         height: 55px;
#         display: block;
#     }
#
#     .swiper-close-btn-container .close-swiper-btn {
#         position: absolute;
#         border-radius: 50%;
#         right: 3px;
#         top: 3px;
#         width: 32px;
#         height: 32px;
#         background-color: #e2e2e2;
#         z-index: 2147483647 !important;
#         pointer-events: auto;
#     }
#
#     .close-swiper-btn:before, .close-swiper-btn:after {
#         position: absolute;
#         left: 15px;
#         content: ' ';
#         height: 20px;
#         width: 2px;
#         top: 6px;
#         background-color: #333;
#         z-index: 2147483647 !important;
#     }
#
#     .close-swiper-btn:before {
#         transform: rotate(45deg);
#     }
#
#     .close-swiper-btn:after {
#         transform: rotate(-45deg);
#     }
#
#     .swiper-container .swiperNavigatorContainer {
#         display: -webkit-box;
#         display: -webkit-flex;
#         display: -ms-flexbox;
#         display: flex;
#         justify-content: center;
#         align-items: center;
#         visibility: hidden;
#         margin-top: 15px;
#         margin-bottom: 15px;
#         pointer-events: auto;
#     }
#
#     #swiper-videos {
#         position: relative;
#         display: flex;
#         align-items: center;
#         cursor: pointer;
#         margin-left: auto;
#         margin-right: auto;
#         width: 75%;
#         max-width: 710px;
#         -webkit-box-orient: vertical;
#         -webkit-box-direction: normal;
#         -webkit-flex-flow: column;
#         -ms-flex-direction: column;
#         flex-direction: column;
#         pointer-events: auto !important;
#     }
#
#         #swiper-videos .swiper-button-prev,
#         #swiper-videos .swiper-button-next {
#             position: relative;
#             --swiper-navigation-size: 18px;
#             --swiper-theme-color: #246a7c;
#             font-size: 18px;
#             font-weight: bold;
#             background-color: #e2e2e2;
#             border-radius: 50%;
#             width: 32px;
#             max-width: 32px;
#             height: 32px;
#             max-height: 32px;
#             left: auto;
#             margin-top: auto;
#             top: auto;
#             right: auto;
#         }
#
#     .videoModal-upper-inner {
#         display: none;
#         z-index: 334;
#         width: 100%;
#         height: 100%;
#         text-align: center;
#     }
#
#     .videoModal-inner- {
#         display: none;
#         width: 100%;
#         height: 100%;
#     }
#
#     .videoModal {
#         position: relative;
#         margin: auto;
#         display: flex;
#         display: -webkit-flex;
#         display: -moz-flex;
#         display: -ms-flex;
#         align-items: center;
#         cursor: pointer;
#         height: 100%;
#         width: 100%;
#         pointer-events: auto;
#     }
#
#     .videoThumbnailLoading {
#         z-index: 332;
#         height: 100%;
#         width: 100%;
#         display: flex;
#         display: -webkit-flex;
#         display: -moz-flex;
#         display: -ms-flex;
#         align-items: center;
#         justify-content: center;
#     }
#
#     .videoThumbnailInner {
#         display: flex;
#         display: -webkit-flex;
#         display: -moz-flex;
#         display: -ms-flex;
#         align-items: center;
#         justify-content: center;
#         height: 100%;
#         width: 100%;
#     }
#
#     .videoThumbnail {
#         height: 100%;
#         width: 100%;
#         margin-left: auto;
#         margin-right: auto;
#         z-index: 335;
#         display: flex;
#         display: -webkit-flex;
#         display: -moz-flex;
#         display: -ms-flex;
#         align-items: center;
#         justify-content: center;
#         display: none;
#     }
#
#     .videoErrorTemplate {
#         display: flex;
#         display: -webkit-flex;
#         display: -moz-flex;
#         display: -ms-flex;
#         z-index: 333;
#         display: none;
#     }
#
#     #swiper-videos-cached-image {
#         position: absolute;
#         left: -9999px;
#         top: -9999px;
#     }
#
#     .ll-power {
#         display: inline-block;
#     }
#
#         .ll-power svg {
#             overflow: visible;
#             height: 20px;
#             width: auto;
#             position: relative;
#         }
#
#             .ll-power svg path,
#             .ll-power svg polygon,
#             .ll-power svg rect {
#                 fill: #333333;
#             }
#
#                 .ll-power svg path.ll-logo-1,
#                 .ll-power svg polygon.ll-logo-1,
#                 .ll-power svg rect.ll-logo-1 {
#                     fill: #008794 !important;
#                 }
#
#                 .ll-power svg path.ll-logo-2,
#                 .ll-power svg polygon.ll-logo-2,
#                 .ll-power svg rect.ll-logo-2 {
#                     fill: #65cbcb !important;
#                 }
#
#     .TimeOnRealtorCon {
#         display: inline-block;
#         margin-bottom: 10px;
#     }
# </style>
# <script type="application/ld+json">
#         {
#             "@context": "http://schema.org/",
#             "@type": "Product",
#             "name": "708 75 St Nicholas Street, Toronto, Ontario M4Y0A5",
#             "image": [ "https://cdn.realtor.ca/listing/TS637793895698200000/reb14/highres/3/h4124943_1.jpg","https://cdn.realtor.ca/listing/TS637793895698200000/reb14/medres/3/h4124943_1.jpg" ],
#             "logo": "https://www.realtor.ca/images/common/email/en-CA/logos/logo_beta2.png",
#             "description": "Welcome to 75 St. Nicholas Street Unit 708.  A luxurious Condo apartment in the heart of the Downtown. Bright and spacious unit.  Unit is 596 sq.ft, 1 Bdrm, 1 Bath and an open Balcony of 136 sq.ft.  Come with 1 parking spot and 1 Locker.  Minutes to Yorkville, U of T, the Subway.  Many amenities within this building - Party/meeting room, Exercise room, Media Room, Visitor parking and more.",
#             "sku": "23993307",
#             "category": "Single Family > Apartment",
#             "url": "https://www.realtor.ca/real-estate/23993307/708-75-st-nicholas-street-toronto",
#             "offers": [
#         {
#             "@type": "Offer",
#             "priceCurrency": "CAD",
#             "price": "687500.00",
#             "businessFunction": "sell",
#             "url": "https://www.realtor.ca/real-estate/23993307/708-75-st-nicholas-street-toronto"
#         } ]
#         }
#         </script>
# <link href="/bundles/css/desktop/page/listing?v=HjoDHkAiDfVMzFBXg4ue7F8SE-LwIf_MW6iw5uhkwKw1&amp;ver=1.0.8066.37080&amp;k=1" rel="stylesheet" type="text/css"/>
# <script src="/bundles/js/desktop/page/listing?v=474B_C5lDSjOJLLbaFrOgay93J1LBa5apEnM_CH6eRs1&amp;ver=1.0.8066.37080&amp;k=1" type="text/javascript"></script>
# <div id="MetaKeyWordsDynamic" style="display: none">23993307</div>
# <div class="noPrint" id="listingBreadcrumbsCon" style="margin: 10px 15px -10px 0px;">
# <span class="ControlBaseWrapper" id="ctrlBreadcrumbs" style="">
# <style>
#     .breadcrumbSep {
#         display: inline-block;
#         color: #cdcdcd;
#     }
#
#     .breadcrumbLink {
#         font-size: .85rem;
#         text-decoration: none;
#     }
# </style>
# <script type="application/ld+json">
#                                 {
#                                     "@context": "https://schema.org",
#                                     "@type": "BreadcrumbList",
#                                     "itemListElement": [
#                                         {
#                                         "@type": "ListItem",
#                                         "position": 1,
#                                         "name": "Ontario",
#                                         "item": "https://www.realtor.ca/explore-canada/ontario"
#                                     },{
#                                         "@type": "ListItem",
#                                         "position": 2,
#                                         "name": "Greater Toronto",
#                                         "item": "https://www.realtor.ca/on/greater-toronto/real-estate"
#                                     },{
#                                         "@type": "ListItem",
#                                         "position": 3,
#                                         "name": "Toronto",
#                                         "item": "https://www.realtor.ca/on/toronto/real-estate"
#                                     },{
#                                         "@type": "ListItem",
#                                         "position": 4,
#                                         "name": "Old Toronto",
#                                         "item": "https://www.realtor.ca/on/toronto/old-toronto/real-estate"
#                                     },{
#                                         "@type": "ListItem",
#                                         "position": 5,
#                                         "name": "Bay Street Corridor",
#                                         "item": "https://www.realtor.ca/on/toronto/bay-street-corridor/real-estate"
#                                     }
#                                     ]
#                                 }</script>
# <a class="breadcrumbLink" href="/" title="Home">
#     Home
#
# </a>
# <div class="breadcrumbSep">/</div>
# <a class="breadcrumbLink" href="/explore-canada/ontario" title="Ontario Real Estate">
#     ON
#
# </a>
# <div class="breadcrumbSep">/</div>
# <a class="breadcrumbLink" href="/on/greater-toronto/real-estate" title="Greater Toronto Real Estate">
#     Greater Toronto
#
# </a>
# <div class="breadcrumbSep">/</div>
# <a class="breadcrumbLink" href="/on/toronto/real-estate" title="Toronto Real Estate">
#     Toronto
#
# </a>
# <div class="breadcrumbSep">/</div>
# <a class="breadcrumbLink" href="/on/toronto/old-toronto/real-estate" title="Old Toronto Real Estate">
#     Old Toronto
#
# </a>
# <div class="breadcrumbSep">/</div>
# <a class="breadcrumbLink" href="/on/toronto/bay-street-corridor/real-estate" title="Bay Street Corridor Real Estate">
#     Bay Street Corridor
#
# </a>
# </span>
# </div>
# <div class="noPrint" id="listingHeaderCon">
# <div id="listingBackBtnCon"></div>
# <div id="listingAddressTitle">
#         708 75 St Nicholas Street
#     </div>
# <div id="listingHeaderRightBtnCon">
# <a class="whiteButtonLeftIcon btn" href="https://www.google.com/maps/dir/?api=1&amp;destination=43.667807%2c-79.386512" id="listingDirectionsBtn" rel="noopener noreferrer" target="_blank"><i class="fa fa-compass"></i>Directions</a>
# <a class="whiteButtonLeftIcon btn" id="listingPrintBtn"><i class="fa fa-print"></i>Print</a>
# <span class="ControlBaseWrapper" id="SocialShare" style="">
# <div class="shareContainer">
# <a class="btnHeader btn right" href="#" id="shareBtn"><i class="fa fa-share-alt"></i>Share</a>
# <div id="shareDialogBox">
# <div class="shareDialogArrow">
# </div>
# <div class="shareButtonsBox">
# <div id="shareButtonsBoxInnerContainer">
# <div id="emailDiv">
# <a id="lnkEmailFriend">
# <img alt="" id="img_email_friend_btn" src="/images/common/icons/svg/icon_email.svg" title="Email a Friend"/>
# </a>
# </div>
# <div id="shareDiv">
# <div alt="Share by Facebook" class="shareIconContainer" id="shareIconContainer_facebook" title="Share by Facebook">
# <a href="https://www.shareaholic.com/api/share/?v=1&amp;apitype=1&amp;apikey=a2430a87e639e6cf0f00273171d97103&amp;service=5&amp;title=Check out this listing&amp;link=https://www.realtor.ca/real-estate/23993307/708-75-st-nicholas-street-toronto?utm_source=facebook&amp;utm_medium=social-organic&amp;utm_campaign=socialsharelisting" id="shareLink_facebook">
# <div class="socialSharingFacebook shareBtnIcon" data-provider="facebook" id="shareIcon_facebook"></div>
# </a>
# </div>
# <div alt="Share by LinkedIn" class="shareIconContainer" id="shareIconContainer_linkedin" title="Share by LinkedIn">
# <a href="https://www.shareaholic.com/api/share/?v=1&amp;apitype=1&amp;apikey=a2430a87e639e6cf0f00273171d97103&amp;service=88&amp;title=Check out this listing&amp;link=https://www.realtor.ca/real-estate/23993307/708-75-st-nicholas-street-toronto?utm_source=linkedin&amp;utm_medium=social-organic&amp;utm_campaign=socialsharelisting" id="shareLink_linkedin">
# <div class="socialSharingLinkedin shareBtnIcon" data-provider="linkedin" id="shareIcon_linkedin"></div>
# </a>
# </div>
# <div alt="Share by Twitter" class="shareIconContainer" id="shareIconContainer_twitter" title="Share by Twitter">
# <a href="https://www.shareaholic.com/api/share/?v=1&amp;apitype=1&amp;apikey=a2430a87e639e6cf0f00273171d97103&amp;service=7&amp;title=Check out this listing&amp;link=https://www.realtor.ca/real-estate/23993307/708-75-st-nicholas-street-toronto?utm_source=twitter&amp;utm_medium=social-organic&amp;utm_campaign=socialsharelisting&amp;shortener=shrlc" id="shareLink_twitter">
# <div class="socialSharingTwitter shareBtnIcon" data-provider="twitter" id="shareIcon_twitter"></div>
# </a>
# </div>
# <div alt="Share by Pinterest" class="shareIconContainer" id="shareIconContainer_pinterest" title="Share by Pinterest">
# <a href="https://www.shareaholic.com/api/share/?v=1&amp;apitype=1&amp;apikey=a2430a87e639e6cf0f00273171d97103&amp;service=309&amp;title=Check out this listing&amp;link=https://www.realtor.ca/real-estate/23993307/708-75-st-nicholas-street-toronto?utm_source=pinterest&amp;utm_medium=social-organic&amp;utm_campaign=socialsharelisting&amp;media_link=https://cdn.realtor.ca/listing/TS637793895698200000/reb14/highres/3/h4124943_1.jpg" id="shareLink_pinterest">
# <div class="socialSharingPinterest shareBtnIcon" data-provider="pinterest" id="shareIcon_pinterest"></div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script>
#
#     var model = new SocialShareModel();
#     model.Campaign = 'ListingLink'
#     model.EmailFriendMedium = ''
#     model.LinkBack = 'https://www.realtor.ca/real-estate/23993307/708-75-st-nicholas-street-toronto' + window.location.hash;
#     model.LinkBackFacebook = 'https://www.realtor.ca/real-estate/23993307/708-75-st-nicholas-street-toronto?utm_source=facebook&utm_medium=social-organic&utm_campaign=socialsharelisting' + window.location.hash;
#     model.LinkBackLinkedIn ='https://www.realtor.ca/real-estate/23993307/708-75-st-nicholas-street-toronto?utm_source=linkedin&utm_medium=social-organic&utm_campaign=socialsharelisting' + window.location.hash;
#     model.LinkBackTwitter ='https://www.realtor.ca/real-estate/23993307/708-75-st-nicholas-street-toronto?utm_source=twitter&utm_medium=social-organic&utm_campaign=socialsharelisting' + window.location.hash;
# ...
# </div>
# </div>
# </div>
# <div class="d_cnt">
# <div class="royalSlider rsDefault default" id="royalslider-def">
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895698200000/reb14/medres/3/h4124943_1.jpg" href="https://cdn.realtor.ca/listing/TS637793895698200000/reb14/highres/3/h4124943_1.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895699570000/reb14/medres/3/h4124943_2.jpg" href="https://cdn.realtor.ca/listing/TS637793895699570000/reb14/highres/3/h4124943_2.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895701070000/reb14/medres/3/h4124943_3.jpg" href="https://cdn.realtor.ca/listing/TS637793895701070000/reb14/highres/3/h4124943_3.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895701170000/reb14/medres/3/h4124943_4.jpg" href="https://cdn.realtor.ca/listing/TS637793895701170000/reb14/highres/3/h4124943_4.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895701300000/reb14/medres/3/h4124943_5.jpg" href="https://cdn.realtor.ca/listing/TS637793895701300000/reb14/highres/3/h4124943_5.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895701530000/reb14/medres/3/h4124943_6.jpg" href="https://cdn.realtor.ca/listing/TS637793895701530000/reb14/highres/3/h4124943_6.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895701700000/reb14/medres/3/h4124943_7.jpg" href="https://cdn.realtor.ca/listing/TS637793895701700000/reb14/highres/3/h4124943_7.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895701870000/reb14/medres/3/h4124943_8.jpg" href="https://cdn.realtor.ca/listing/TS637793895701870000/reb14/highres/3/h4124943_8.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895702030000/reb14/medres/3/h4124943_9.jpg" href="https://cdn.realtor.ca/listing/TS637793895702030000/reb14/highres/3/h4124943_9.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895698400000/reb14/medres/3/h4124943_10.jpg" href="https://cdn.realtor.ca/listing/TS637793895698400000/reb14/highres/3/h4124943_10.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895698430000/reb14/medres/3/h4124943_11.jpg" href="https://cdn.realtor.ca/listing/TS637793895698430000/reb14/highres/3/h4124943_11.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895698670000/reb14/medres/3/h4124943_12.jpg" href="https://cdn.realtor.ca/listing/TS637793895698670000/reb14/highres/3/h4124943_12.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895698770000/reb14/medres/3/h4124943_13.jpg" href="https://cdn.realtor.ca/listing/TS637793895698770000/reb14/highres/3/h4124943_13.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895698930000/reb14/medres/3/h4124943_14.jpg" href="https://cdn.realtor.ca/listing/TS637793895698930000/reb14/highres/3/h4124943_14.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895699100000/reb14/medres/3/h4124943_15.jpg" href="https://cdn.realtor.ca/listing/TS637793895699100000/reb14/highres/3/h4124943_15.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895699130000/reb14/medres/3/h4124943_16.jpg" href="https://cdn.realtor.ca/listing/TS637793895699130000/reb14/highres/3/h4124943_16.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895699170000/reb14/medres/3/h4124943_17.jpg" href="https://cdn.realtor.ca/listing/TS637793895699170000/reb14/highres/3/h4124943_17.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895699230000/reb14/medres/3/h4124943_18.jpg" href="https://cdn.realtor.ca/listing/TS637793895699230000/reb14/highres/3/h4124943_18.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895699370000/reb14/medres/3/h4124943_19.jpg" href="https://cdn.realtor.ca/listing/TS637793895699370000/reb14/highres/3/h4124943_19.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895699730000/reb14/medres/3/h4124943_20.jpg" href="https://cdn.realtor.ca/listing/TS637793895699730000/reb14/highres/3/h4124943_20.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895699900000/reb14/medres/3/h4124943_21.jpg" href="https://cdn.realtor.ca/listing/TS637793895699900000/reb14/highres/3/h4124943_21.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895700100000/reb14/medres/3/h4124943_22.jpg" href="https://cdn.realtor.ca/listing/TS637793895700100000/reb14/highres/3/h4124943_22.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895700270000/reb14/medres/3/h4124943_23.jpg" href="https://cdn.realtor.ca/listing/TS637793895700270000/reb14/highres/3/h4124943_23.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895700430000/reb14/medres/3/h4124943_24.jpg" href="https://cdn.realtor.ca/listing/TS637793895700430000/reb14/highres/3/h4124943_24.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895700600000/reb14/medres/3/h4124943_25.jpg" href="https://cdn.realtor.ca/listing/TS637793895700600000/reb14/highres/3/h4124943_25.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895700770000/reb14/medres/3/h4124943_26.jpg" href="https://cdn.realtor.ca/listing/TS637793895700770000/reb14/highres/3/h4124943_26.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895700870000/reb14/medres/3/h4124943_27.jpg" href="https://cdn.realtor.ca/listing/TS637793895700870000/reb14/highres/3/h4124943_27.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895700900000/reb14/medres/3/h4124943_28.jpg" href="https://cdn.realtor.ca/listing/TS637793895700900000/reb14/highres/3/h4124943_28.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895701000000/reb14/medres/3/h4124943_29.jpg" href="https://cdn.realtor.ca/listing/TS637793895701000000/reb14/highres/3/h4124943_29.jpg"></a>
# <a class="rsImg" data-rstmb="https://cdn.realtor.ca/listing/TS637793895701130000/reb14/medres/3/h4124943_30.jpg" href="https://cdn.realtor.ca/listing/TS637793895701130000/reb14/highres/3/h4124943_30.jpg"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="noPrint" id="similarListingsOuterCon" style="margin-top: 30px; min-height: 560px;">
# <h2 style="font-size: 1.9rem; font-weight: normal; margin: 0px 0px 0px 15px; text-align: center;">Similar Listings</h2>
# <div class="fullWidth" id="similarListingsCon">
# <div class="sk-spinning-circle" style="margin: 60px auto;"></div>
# </div>
# </div>
# <span class="ControlBaseWrapper" id="realtorContactBar" style="">
# <div class="RealtorContactBar noPrint">
# <div class="RealtorContactBar_Main">
# <div class="RealtorContactBar_Left">
# <img src="https://cdn.realtor.ca/individual/TS636437080200000000/lowres/1122696.jpg"/>
# </div>
# <div class="RealtorContactBar_Center">
# <div class="RealtorContactBar_RealtorName">Kevin Wedzinga</div>
# <div><a class="RealtorContactBar_RealtorEmailBtn lnkEmailRealtor blueRoundedBtn btn" href="#"><span class="realtorCardFooterLinkText">Contact</span></a></div>
# </div>
# <div class="RealtorContactBar_Right">
# <img alt="" class="RealtorContactBar_CloseIcon" src="/images/common/icons/svg/x-gray.svg"/>
# </div>
# </div>
# </div>
# <script>
#     var FloatingContactRealtorBar = new Controls.Desktop.FloatingContactRealtorBar(null, 'realtorContactBar',
#         '1525383',
#         '23993307',
#         'H4124943');
# </script>
# </span>
# <script>
#
#     (function ($) {
#
#         var model = new ListingModel('23993307',
#                 '14',
#                 'H4124943', '1525383',
#                 '43.667807', '-79.386512',
#                 'ON', '300',
#                 '35204598', '687500.00',
#                 'Toronto');
#         model.floorPlanIcon = $("#lnkPropertyDetailsHdrIcon_FP");
#
#
#         model.multimedia.push(new MultimediaModel('https://youriguide.com/708_75_st_nicholas_st_toronto_on/',
#                 "videoModal_0",
#             VideoLoadingDisplay.Yes,
#             VideoDisplay.VideoWithThumbnail,
#             VideoLoadingType.LoadingNow));
#         model.multimedia[model.multimedia.length - 1].CachedImageContainerId = "swiper-videos-cached-image";
#         model.multimedia[model.multimedia.length - 1].AppendCachedImageContainerAfterId = "swiper-videos";
#
#         model.multimedia[model.multimedia.length - 1].setContentOptions("", "videoThumbnailLoading_0",
#                         "videoThumbnail_0",
#                         "videoModal_0-upper-inner",
#                         "videoModal_0-inner",
#                         "play_button_0",
#                         "videoErrorMainContainer_0");
#
#
#         model.hasOpenHouse = false;
#         var ListingPage = new Pages.Desktop.Listing(model, 'MainContent_ctl00_ctl00');
#     }(jQuery));
# </script>
# </span>
# </div>
# <!-- Begin comScore Tag --><script>var _comscore = _comscore || [];
#                             _comscore.push({ c1: "2", c2: "6035098" });
#                             (function() {
#                              var s = document.createElement("script"), el =
#                             document.getElementsByTagName("script")[0]; s.async = true;
#                              s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") +
#                             ".scorecardresearch.com/beacon.js";
#                              el.parentNode.insertBefore(s, el);
#                             })();
#                             </script>
# <noscript>
# <img alt="" src="http://b.scorecardresearch.com/p?c1=2&amp;c2=6035098&amp;cv=2.0&amp;cj=1">
# </img></noscript>
# <!-- End comScore Tag --><span class="ControlBaseWrapper" id="ctl36" style="">
# <footer class="" id="footer">
# <div class="noPrint" id="footerLinkCon">
# <div class="footerCol">
# <a class="footerColItem" href="/realtors" id="lnkFooter_FindARealtor">
#     Find a REALTOR<sup>®</sup></a>
# <a class="footerColItem" href="#" id="lnkFooter_CreateAccount">Create An Account</a>
# <a class="footerColItem" href="/tips-for-buyers" id="lnkFooter_BuyerInfo">Tips for Buyers</a>
# <a class="footerColItem" href="/tips-for-sellers" id="lnkFooter_SellerInfo">Tips for Sellers</a>
# <a class="footerColItem" href="/commercial-resources" id="lnkFooter_CommRes">Commercial Resources</a>
# <a class="footerColItem" href="/canada/real-estate" id="lnkFooter_ExploreCanada">Canada Real Estate</a>
# <a class="footerColItem" href="/global-buyers" id="lnkFooter_GobalBuyers">Global Buyers</a>
# </div>
# <div class="footerCol">
# <a class="footerColItem" href="/blog" id="lnkFooter_Blog">Living Room Blog</a>
# <a class="footerColItem" href="/about-realtorca" id="lnkFooter_AboutUs">About REALTOR.ca</a>
# <a class="footerColItem" href="/ddf" id="lnkFooter_DDF">REALTOR.ca DDF®</a>
# <a class="footerColItem" href="https://www.crea.ca/about/organization/" id="lnkFooter_AboutCREA" rel="noopener noreferrer" target="_blank">About CREA</a>
# <a class="footerColItem" href="/realtor-code-of-ethics" id="lnkFooter_RealtorEthics">
#     REALTOR<sup>®</sup> Code of Ethics</a>
# <a class="footerColItem" href="http://www.realtorscare.ca/" id="lnkFooter_RealtorsCare" rel="noopener noreferrer" target="_blank">REALTORS Care<sup>®</sup></a>
# <a class="footerColItem" href="javascript:FSR.launchFeedback('BgDKUqs1uIVqao7MDtdKgsXCMR0VT9YG');" id="lnkSendFeedback">Send Feedback</a>
# </div>
# <div class="footerCol">
# <a class="footerColItem" href="/contact-us" id="lnkFooter_ContactUs">Contact Us</a>
# <a class="footerColItem" href="/frequently-asked-questions" id="lnkFooter_FAQ">FAQ</a>
# <a class="footerColItem" href="/privacy-policy" id="lnkFooter_Privacy">Privacy Policy</a>
# <a class="footerColItem" href="/terms-of-use" id="lnkFooter_TOS">Terms of Use</a>
# <a class="footerColItem" href="/site-map" id="lnkFooter_Sitemap">Sitemap</a>
# </div>
# </div>
# <div class="noPrint" id="footerSocialAppCon">
# <div id="footerSocialAppConLeft">
# <div class="footerLabel">Download the REALTOR.ca app</div>
# <div class="footerContent">
# <a href="http://itunes.apple.com/ca/app/realtor-ca/id408873309?mt=8" rel="noopener noreferrer" target="_blank">
# <img alt="Apple Store logo" src="/images/en-ca/apple_app_store.svg" style="height: 40px;"/>
# </a>
# <a href="https://play.google.com/store/apps/details?id=ca.crea.app.consumer&amp;feature=search_result&amp;hl=en" rel="noopener noreferrer" target="_blank">
# <img alt="Google Play logo" src="/images/en-ca/google_play.svg" style="height: 40px;"/>
# </a>
# </div>
# </div>
# <div id="footerSocialAppConRight">
# <div class="footerLabel">Stay Connected</div>
# <div class="footerContent">
# <a href="https://facebook.com/realtordotca" rel="noopener noreferrer" target="_blank">
# <img alt="Facebook logo" id="img_footer_facebook" src="/images/common/icons/svg/icon-facebook-transparent.svg" style="height: 41px;"/></a>
# <a href="https://twitter.com/realtordotca" rel="noopener noreferrer" target="_blank">
# <img alt="Twitter logo" id="img_footer_twitter" src="/images/common/icons/svg/icon-twitter-transparent.svg" style="height: 41px;"/></a>
# <a href="https://instagram.com/realtordotca" rel="noopener noreferrer" target="_blank">
# <img alt="Instagram logo" id="img_footer_instagram" src="/images/common/icons/svg/icon-instagram-transparent.svg" style="height: 41px;"/></a>
# <a href="https://pinterest.com/realtordotca" rel="noopener noreferrer" target="_blank">
# <img alt="Pinterest logo" id="img_footer_pinterest" src="/images/common/icons/svg/icon-pinterest-transparent.svg" style="height: 41px;"/></a>
# </div>
# </div>
# </div>
# <div id="footerLegalCon">
# <div id="footerMLSCon">
# <img alt="" id="footerMLSLogo" src="/images/common/icons/svg/mls-logo-footer.svg"/>
# <div id="footerMLSText">
#                 Trusted listings from REALTOR® Agents. <br>The MLS® mark and associated logos identify professional services rendered by REALTOR® members of CREA to effect the purchase, sale and lease of real estate as part of a cooperative selling system.
#             </br></div>
# </div>
# <div class="" id="footerRealtorCon">
# <img alt="" class="" id="footerRealtorLogo" src="/images/common/icons/svg/realtor-r-footer.svg"/>
# <div class="" id="footerRealtorText">
#                 ©2022 The Canadian Real Estate Association. All rights reserved. The trademarks REALTOR®, REALTORS® and the REALTOR® logo are controlled by CREA and identify real estate professionals who are members of CREA.
#             </div>
# </div>
# </div>
# </footer>
# <script>
#     var footer = new Controls.Desktop.Footer(null, 'ctl36');
# </script>
# </span>
# </div>
# <div id="ToastMessage"></div>
# <!-- Version: Realtor 7 (Git) | 20220131.3 | f3c8b3c3913e8cc85c38dc9ec25ab1af4f885184 | Monday, January 31, 2022 3:34:40 PM -->
# </form>
# <div class="feedbackBtnContainer noPrint" id="feedbackSmall" style="display: none;">
# <span class="feedbackText" onclick="FSR.launchFeedback('BgDKUqs1uIVqao7MDtdKgsXCMR0VT9YG');" style="cursor: pointer; color: #fff; padding: 0;">Feedback</span>
# </div>
# <div class="feedbackBtnContainer noPrint" id="feedbackLarge" style="display: none;">
# <span class="feedbackText" onclick="FSR.launchFeedback('BgDKUqs1uIVqao7MDtdKgsXCMR0VT9YG');" style="cursor: pointer; color: #fff; padding: 0;">Feedback</span>
# <div class="feedbackCloseBtn" src="//:0" style="margin: 0px 7px 0px 0; cursor: pointer;"></div>
# </div>
# <script>
#         if ('serviceWorker' in navigator) {
#
#
#             window.addEventListener('load', function () {
#                 navigator.serviceWorker.register('/serviceworker.js', { scope: "/" }).then(function (registration) {
#                     console.log('ServiceWorker registration successful with scope: ', registration.scope);
#                 }, function (err) {
#                     console.log('ServiceWorker registration failed: ', err);
#                 });
#             });
#         }
#     </script>
# </body>
# </html>

# %%
sale_property = sale_soup.find_all(attrs={'id':'GTMDataLayerCode'})
sale_property
# Out:
# [<script id="GTMDataLayerCode" type="text/javascript">
#                           window.dataLayer = window.dataLayer || [];
#                          dataLayer.push({
#                             event: 'propertyDetailsLoaded',
#                             pagePath: (location.pathname + (location.search || '')),
#                             pageTitle: document.title,
#                             visitor: {
#                                 loggedIn: 'No',
#                                 userId: '',
#                                 favouriteCountValue: '0',
#                                 saveSearchCountValue: '0'
#                             },
#                             site: {
#                                 language: 'EN'
#                             },
#                              property: {
#                                  propertyID: '23993307',
#                                  listingID: 'H4124943',
#                                  propertyType: 'Single Family',
#                                  price: '687500.00',
#                                  leasePrice: '',
#                                  buildingType: 'Apartment',
#                                  neighbourhood: '',
#                                  bathrooms: '1',
#                                  bedrooms: '1',
#                                  communityFeatures: '',
#                                  nearbyAmenities: 'Hospital, Public Transit, Schools',
#                                  storeys: '1',
#                                  walkscore: '',
#                                  transitscore: '',
#                                  machineryIncluded: '',
#                                  rentalEquipment: 'None',
#                                  parkingType: 'Underground',
#                                  majorBusinessType: '',
#                                  minorBusinessType: '',
#                                  totalUnits: '',
#                                  landSize: '0 x 0',
#                                  zoningType:  '',
#                                  interiorFloorSpace: '596 sqft',
#                                  exteriorBuildingSize:  '596 sqft',
#                                  franchise: '',
#                                  buildingAmenities: 'Exercise Centre, Party Room',
#                                  buildingStyle: '',
#                                  basementDevelopment: '',
#                                  notificationUpdate: 'no',
#                                  anchor: '',
#                                  retailStorefront: '',
#                                  clearCeilingHeight: '',
#                                  hasphoto: 'yes' ,
#                                  photos: '30' ,
#                                  multimediaFeatures: 'Video,FloorPlan',
#                                  listingVideoType: 'iGuide',
#                                  city: 'Toronto',
#                                  province: 'Ontario',
#                                  soldData: 'no',
#                                  hasAlternateFeatureSheet: 'yes',
#                                  hasOpenHouse: 'no',
#                                  hasVirtualOpenHouse: 'no',
#                                  hasCMHCFTHBBanner: 'yes',
#                                  hasTDpreApprovalIcon: 'no',
#                                  hasActiveVirtualOpenHouse: 'no'
#                              }
#                          });
#                      </script>]

# %%
property_lst = sale_property[0].string.split("property: {")[1].split('\r\n')[1:-3]
#property_lst

property_dict = {}
for i in range(len(property_lst)):
    property_lst[i] = property_lst[i].strip(", ")
    tmp = property_lst[i].split(": ")
    property_dict[tmp[0]] = tmp[1].strip("''")
    
    
property_dict
# Out:
# {'propertyID': '23993307',
#  'listingID': 'H4124943',
#  'propertyType': 'Single Family',
#  'price': '687500.00',
#  'leasePrice': '',
#  'buildingType': 'Apartment',
#  'neighbourhood': '',
#  'bathrooms': '1',
#  'bedrooms': '1',
#  'communityFeatures': '',
#  'nearbyAmenities': 'Hospital, Public Transit, Schools',
#  'storeys': '1',
#  'walkscore': '',
#  'transitscore': '',
#  'machineryIncluded': '',
#  'rentalEquipment': 'None',
#  'parkingType': 'Underground',
#  'majorBusinessType': '',
#  'minorBusinessType': '',
#  'totalUnits': '',
#  'landSize': '0 x 0',
#  'zoningType': ' ',
#  'interiorFloorSpace': '596 sqft',
#  'exteriorBuildingSize': " '596 sqft",
#  'franchise': '',
#  'buildingAmenities': 'Exercise Centre, Party Room',
#  'buildingStyle': '',
#  'basementDevelopment': '',
#  'notificationUpdate': 'no',
#  'anchor': '',
#  'retailStorefront': '',
#  'clearCeilingHeight': '',
#  'hasphoto': 'yes',
#  'photos': '30',
#  'multimediaFeatures': 'Video,FloorPlan',
#  'listingVideoType': 'iGuide',
#  'city': 'Toronto',
#  'province': 'Ontario',
#  'soldData': 'no',
#  'hasAlternateFeatureSheet': 'yes',
#  'hasOpenHouse': 'no',
#  'hasVirtualOpenHouse': 'no',
#  'hasCMHCFTHBBanner': 'yes',
#  'hasTDpreApprovalIcon': 'no',
#  'hasActiveVirtualOpenHouse': 'no'}

# %% [markdown]
# ### get more details - building

# %%
# get address
sale_address = sale_soup.find(attrs={'class':'listingTopDetailsLeft'}).h1.contents # can also use .text
sale_address
# Out:
# ['708 75 St Nicholas Street', <br/>, 'Toronto, Ontario M4Y0A5']

# %% [markdown]
# ### loop through each building to extract info

# %%
# key_lst = list(full_dict.keys())
# print(key_lst)
key_lst = ['Address1', 'Address2', 'propertyID', 'listingID', 'propertyType', 'price', 'leasePrice', 'buildingType', 'neighbourhood', 'bathrooms', 'bedrooms', 'communityFeatures', 'nearbyAmenities', 'storeys', 'walkscore', 'transitscore', 'machineryIncluded', 'rentalEquipment', 'parkingType', 'majorBusinessType', 'minorBusinessType', 'totalUnits', 'landSize', 'zoningType', 'interiorFloorSpace', 'exteriorBuildingSize', 'franchise', 'buildingAmenities', 'buildingStyle', 'basementDevelopment', 'notificationUpdate', 'anchor', 'retailStorefront', 'clearCeilingHeight', 'hasphoto', 'photos', 'multimediaFeatures', 'listingVideoType', 'city', 'province', 'soldData', 'hasAlternateFeatureSheet', 'hasOpenHouse', 'hasVirtualOpenHouse', 'hasCMHCFTHBBanner', 'hasTDpreApprovalIcon', 'hasActiveVirtualOpenHouse', 'Property Type', 'Building Type', 'Community Name', 'Title', 'Annual Property Taxes', 'Parking Type', 'Time on REALTOR.ca', 'Above Grade', 'Total', 'Features', 'Building Amenities', 'Cooling', 'Heating Type', 'Exterior Finish', 'Pool Type', 'Community Features', 'Amenities Nearby', 'Maintenance Fees', 'Maintenance Management Company', 'Total Parking Spaces']

# %%
headers2 = {
        'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
        'referrer': 'https://google.com',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'en-CA,en;q=0.8',
        'Pragma': 'no-cache',
    }

# %%
sales_info = []

for i in range(5):  #len(sales)
    print(i)
    sale = sales[i]
    link = sale.attrs['href']
    response=requests.get('https://www.realtor.ca/' + link,headers=headers2)
    sale_soup=BeautifulSoup(response.content)
    
    # extract from json property dictionary
    sale_property = sale_soup.find_all(attrs={'id':'GTMDataLayerCode'})
    property_lst = sale_property[0].string.split("property: {")[1].split('\r\n')[1:-3]
    property_dict = {}
    for i in range(len(property_lst)):
        property_lst[i] = property_lst[i].strip(", ")
        tmp = property_lst[i].split(": ")
        property_dict[tmp[0]] = tmp[1].strip("''")
    
    # extract more info
    sale_address = sale_soup.find(attrs={'class':'listingTopDetailsLeft'}).h1.contents
    address_dict = {'Address1': sale_address[0], 'Address2': sale_address[2]}
    soup_building_info = sale_soup.find_all(attrs={'class':'propertyDetailsSectionContentSubCon'})
    building_info_dict = dict()
    for info in soup_building_info:
        building_info_dict[info.find(attrs={'class':'propertyDetailsSectionContentLabel'}).string] = info.find(attrs={'class':'propertyDetailsSectionContentValue'}).text    
    
    full_dict = address_dict.copy() 
    full_dict.update(property_dict)
    full_dict.update(building_info_dict)
    
    # add missing field with ''
    for key in key_lst:
        if key not in list(full_dict.keys()):
            full_dict[key] = ''
            
    reordered_dict = {k: full_dict[k] for k in key_lst}
    
    sales_info.append(reordered_dict)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
### save sales info to csv
# https://www.geeksforgeeks.org/how-to-save-a-python-dictionary-to-a-csv-file/
import csv

with open('realtor.csv', 'w') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames = key_lst)
    writer.writeheader()
    writer.writerows(sales_info)
